# %% [markdown]
# ## The Reuters Dataset

# %% [markdown]
# Loading the Reuters dataset

# %%
from keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words = 10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %% [markdown]
# Decoding newswires back to text

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = ' '.join([reverse_word_index.get(i - 3, '?') for i in train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters_word_index.json
# 550378/550378 [==============================] - 0s 0us/step

# %%
decoded_newswire
# Out:
# '? ? ? said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %%
train_labels[10]
# Out:
# 3

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# Encoding the data

# %%
import numpy as np

def vectorize_sequences(sequences, dimension = 10000):
    results = np.zeros((len(sequences), dimension))

    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1

    return results

# vectorize training data
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
from keras.utils.np_utils import to_categorical

# vectorize training labels
one_hot_train_labels = to_categorical(train_labels)

# vectorize test labels
one_hot_test_labels = to_categorical(test_labels)

# %% [markdown]
# ## Building your network

# %% [markdown]
# Model definition

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation = 'relu', input_shape = (10000,)))
model.add(layers.Dense(64, activation = 'relu'))
model.add(layers.Dense(46, activation = 'softmax'))

# %% [markdown]
# Compiling the model

# %%
model.compile(optimizer = 'rmsprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# ## Validating your approach

# %% [markdown]
# Setting aside a validation set

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %% [markdown]
# Training the model

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 20,
                    batch_size = 512,
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 2s 60ms/step - loss: 2.8750 - accuracy: 0.5023 - val_loss: 2.0020 - val_accuracy: 0.6350
# Epoch 2/20
# 16/16 [==============================] - 1s 46ms/step - loss: 1.5510 - accuracy: 0.7027 - val_loss: 1.3909 - val_accuracy: 0.7150
# Epoch 3/20
# 16/16 [==============================] - 1s 46ms/step - loss: 1.0942 - accuracy: 0.7706 - val_loss: 1.1581 - val_accuracy: 0.7500
# Epoch 4/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.8524 - accuracy: 0.8193 - val_loss: 1.0549 - val_accuracy: 0.7800
# Epoch 5/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.6743 - accuracy: 0.8649 - val_loss: 0.9919 - val_accuracy: 0.7950
# Epoch 6/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.5329 - accuracy: 0.8906 - val_loss: 0.9659 - val_accuracy: 0.7900
# Epoch 7/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.4306 - accuracy: 0.9124 - val_loss: 0.8912 - val_accuracy: 0.8160
# Epoch 8/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.3451 - accuracy: 0.9272 - val_loss: 0.9106 - val_accuracy: 0.8090
# Epoch 9/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2839 - accuracy: 0.9386 - val_loss: 0.8691 - val_accuracy: 0.8260
# Epoch 10/20
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2420 - accuracy: 0.9463 - val_loss: 0.8927 - val_accuracy: 0.8180
# Epoch 11/20
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2092 - accuracy: 0.9514 - val_loss: 0.9292 - val_accuracy: 0.8050
# Epoch 12/20
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1843 - accuracy: 0.9518 - val_loss: 0.9249 - val_accuracy: 0.8180
# Epoch 13/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1634 - accuracy: 0.9546 - val_loss: 0.9259 - val_accuracy: 0.8120
# Epoch 14/20
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1510 - accuracy: 0.9545 - val_loss: 0.9444 - val_accuracy: 0.8190
# Epoch 15/20
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1422 - accuracy: 0.9565 - val_loss: 0.9733 - val_accuracy: 0.8160
# Epoch 16/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1293 - accuracy: 0.9568 - val_loss: 1.0259 - val_accuracy: 0.8090
# Epoch 17/20
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1308 - accuracy: 0.9567 - val_loss: 1.0072 - val_accuracy: 0.8050
# Epoch 18/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1184 - accuracy: 0.9584 - val_loss: 1.0266 - val_accuracy: 0.8120
# Epoch 19/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1159 - accuracy: 0.9558 - val_loss: 1.1088 - val_accuracy: 0.8000
# Epoch 20/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1155 - accuracy: 0.9587 - val_loss: 1.1161 - val_accuracy: 0.8020

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Plotting the training and validation loss

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# Plotting the training and validation accuracy

# %%
plt.clf()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'b', label = 'Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# Retraining a model from scratch

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation = 'relu', input_shape = (10000,)))
model.add(layers.Dense(64, activation = 'relu'))
model.add(layers.Dense(46, activation = 'softmax'))

model.compile(optimizer = 'rmsprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs = 9,
                    batch_size = 512,
                    validation_data = (x_val, y_val))

results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# Epoch 1/9
# 16/16 [==============================] - 1s 55ms/step - loss: 2.7059 - accuracy: 0.5005 - val_loss: 1.7849 - val_accuracy: 0.6230
# Epoch 2/9
# 16/16 [==============================] - 1s 46ms/step - loss: 1.4508 - accuracy: 0.7085 - val_loss: 1.2902 - val_accuracy: 0.7310
# Epoch 3/9
# 16/16 [==============================] - 1s 46ms/step - loss: 1.0652 - accuracy: 0.7796 - val_loss: 1.1084 - val_accuracy: 0.7680
# Epoch 4/9
# 16/16 [==============================] - 1s 46ms/step - loss: 0.8344 - accuracy: 0.8246 - val_loss: 1.0211 - val_accuracy: 0.7790
# Epoch 5/9
# 16/16 [==============================] - 1s 49ms/step - loss: 0.6623 - accuracy: 0.8642 - val_loss: 0.9551 - val_accuracy: 0.8020
# Epoch 6/9
# 16/16 [==============================] - 1s 47ms/step - loss: 0.5291 - accuracy: 0.8936 - val_loss: 0.9454 - val_accuracy: 0.7910
# Epoch 7/9
# 16/16 [==============================] - 1s 48ms/step - loss: 0.4212 - accuracy: 0.9132 - val_loss: 0.8798 - val_accuracy: 0.8180
# Epoch 8/9
# 16/16 [==============================] - 1s 44ms/step - loss: 0.3455 - accuracy: 0.9272 - val_loss: 0.8696 - val_accuracy: 0.8170
# Epoch 9/9
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2813 - accuracy: 0.9392 - val_loss: 0.8698 - val_accuracy: 0.8140
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0082 - accuracy: 0.7801

# %%
results
# Out:
# [1.0082216262817383, 0.780053436756134]

# %% [markdown]
# Generating predictions

# %%
predictions = model.predict(x_test)
# Out:
# 71/71 [==============================] - 0s 3ms/step

# %%
# each entry in predictions has a vecotry of length 46
predictions[0].shape
# Out:
# (46,)

# %%
# The coefficients sum to 1
np.sum(predictions[0])
# Out:
# 1.0

# %%
# The largest entry is the predicted class - class with highest probability
np.argmax(predictions[0])
# Out:
# 3
